# %%
import pandas as pd
import numpy as np
import os
import pycountry

# %%
RAW_FOLDER = "raw_data"
OUTPUT_CSV = "final_panel_2010_2024.csv"
OUTPUT_XLSX = "final_panel_2010_2024.xlsx"

YEAR_START, YEAR_END = 2010, 2024

# %%
VARIABLE_NAMES = {
    "poverty_nat": "Poverty headcount ratio at national poverty lines",
    "poverty_83": "Poverty headcount ratio at 8.30",
    "emp_share": "Employment by industry",
    "food_price": "Food price index",
    "ag_va": "Gross Agri Production Value Added",
    "wage_food": "Wage in the food industry",
    "gdp_pc": "GDP per capita (current US$)",
    "gdp_growth": "GDP per capita growth (annual %)",
    "inflation": "Inflation, GDP deflator (annual %)",
    "enrollment": "Secondary enrollment",
    "transfers": "Subsidies and other transfers",
    "urban": "Urban population (% of total population)",
    "precip": "Average precipitation in depth (mm per year)",
    "lpi": "Logistic performance index",
    "region": "region",
    "income_class": "income_class"
}

# %%
poverty_nat = pd.read_excel('raw_data\\Poverty headcount ratio at national poverty lines.xls')

# %%
country_list = poverty_nat['Country Name'].unique()
print(f"Number of countries in master list: {len(country_list)}")
print("First 5 countries:", country_list[:5])
# Out:
# Number of countries in master list: 65
# First 5 countries: ['Albania' 'Argentina' 'Armenia' 'Austria' 'Belgium']

# %%
poverty_nat.to_excel('preclean_data\\Poverty headcount ratio at national poverty lines.xlsx')

# %%
def filter_countries(df, country_column='Country Name'):
    """
    Filters a dataframe to keep only countries in the country_list
    """
    # Check if the specified country column exists
    if country_column not in df.columns:
        print(f"Warning: Column '{country_column}' not found. Available columns: {df.columns.tolist()}")
        return df
    
    # Filter the dataframe
    filtered_df = df[df[country_column].isin(country_list)].copy()
    
    print(f"Original shape: {df.shape}, Filtered shape: {filtered_df.shape}")
    print(f"Countries kept: {filtered_df[country_column].nunique()}")
    
    return filtered_df

# %%
poverty_83 = pd.read_excel('raw_data\\Poverty headcount ratio at 8.30.xlsx',
                           na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(poverty_83.columns.to_list())
# Out:
# ['Series Name', 'Series Code', 'Country Name', 'Country Code', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]', '2024 [YR2024]']

# %%
poverty_83 = filter_countries(poverty_83, 'Country Name')
# Out:
# Original shape: (271, 19), Filtered shape: (65, 19)
# Countries kept: 65

# %%
poverty_83 = poverty_83.rename(columns={'2010 [YR2010]': '2010',
                           '2011 [YR2011]': '2011',
                           '2012 [YR2012]': '2012',
                           '2013 [YR2013]': '2013',
                           '2014 [YR2014]': '2014',
                           '2015 [YR2015]': '2015',
                           '2016 [YR2016]': '2016',
                           '2017 [YR2017]': '2017',
                           '2018 [YR2018]': '2018',
                           '2019 [YR2019]': '2019',
                           '2020 [YR2020]': '2020',
                           '2021 [YR2021]': '2021',
                           '2022 [YR2022]': '2022',
                           '2023 [YR2023]': '2023',
                           '2024 [YR2024]': '2024'})
poverty_83.head()
# Out:
#                                           Series Name  Series Code  \
# 1   Poverty headcount ratio at $8.30 a day (2021 P...  SI.POV.UMIC
# 7   Poverty headcount ratio at $8.30 a day (2021 P...  SI.POV.UMIC
# 8   Poverty headcount ratio at $8.30 a day (2021 P...  SI.POV.UMIC
# 11  Poverty headcount ratio at $8.30 a day (2021 P...  SI.POV.UMIC
# 17  Poverty headcount ratio at $8.30 a day (2021 P...  SI.POV.UMIC
#
#    Country Name Country Code  2010  2011  2012  2013  2014  2015  2016  2017  \
# 1       Albania          ALB   NaN   NaN  45.9   NaN  46.5  32.8  32.9  32.7
# 7     Argentina          ARG  13.6  11.3  10.3  10.4  11.7   NaN  11.5   9.8
# 8       Armenia          ARM  66.0  63.0  59.6  57.4  55.2  50.7  45.9  52.7
# 11      Austria          AUT   0.8   1.0   1.1   0.7   0.7   1.2   1.3   0.7
# 17      Belarus          BLR  18.0  14.6   9.2   5.8   5.4   6.8   7.4   6.2
#
#     2018  2019  2020  2021  2022  2023  2024
# 1   24.1  21.5  19.9   NaN   NaN   NaN   NaN
# 7   12.5  14.9  18.3  14.2  13.9  16.4  15.2
# 8   52.8  57.1  58.2  57.0  55.7  56.9   NaN
# 11   1.2   0.9   1.1   1.1   1.1   1.0   NaN
# 17   4.3   3.9   2.6   NaN   NaN   NaN   NaN

# %%
poverty_83.to_excel('preclean_data\\Poverty headcount ratio at 8.30.xlsx', index=False)

# %%
ag_va = pd.read_excel('raw_data\\Share of Food VA in GDP.xls', 
                      na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(ag_va.columns.to_list())
# Out:
# ['Country Name', 'Indicator', 'Year', 'Value']

# %%
ag_va.head()
# Out:
#   Country Name                                  Indicator  Year      Value
# 0  Afghanistan  Agriculture Share of GDP US$, 2015 prices  2010  29.927071
# 1  Afghanistan  Agriculture Share of GDP US$, 2015 prices  2011  29.068881
# 2  Afghanistan  Agriculture Share of GDP US$, 2015 prices  2012  27.282895
# 3  Afghanistan  Agriculture Share of GDP US$, 2015 prices  2013  27.975367
# 4  Afghanistan  Agriculture Share of GDP US$, 2015 prices  2014  28.394494

# %%
ag_va = ag_va.pivot(index=['Country Name', 'Indicator'], columns='Year').reset_index()
ag_va.head()
# Out:
#      Country Name                                  Indicator      Value  \
# Year                                                               2010
# 0     Afghanistan  Agriculture Share of GDP US$, 2015 prices  29.927071
# 1         Albania  Agriculture Share of GDP US$, 2015 prices  18.838472
# 2         Algeria  Agriculture Share of GDP US$, 2015 prices   9.692806
# 3         Andorra  Agriculture Share of GDP US$, 2015 prices   0.466561
# 4          Angola  Agriculture Share of GDP US$, 2015 prices   7.517585
#
#                                                                         \
# Year       2011       2012       2013       2014       2015       2016
# 0     29.068881  27.282895  27.975367  28.394494  24.240142  26.525034
# 1     19.247593  20.001970  20.028236  20.065053  19.780173  19.537605
# 2     10.512314  10.898647  11.471144  11.327478  11.578715  11.421639
# 3      0.490616   0.601234   0.585626   0.537684   0.513420   0.521889
# 4      7.839903   7.733747   7.559591   8.359599   9.122534   9.722951
#
#                                                                         \
# Year       2017       2018       2019       2020       2021       2022
# 0     26.991481  26.587779  30.606768  32.618118  37.127710  36.999484
# 1     18.979104  18.460519  18.196361  19.071596  17.826641  17.010490
# 2     11.342714  11.600503  11.659044  11.900684  11.066839  11.231845
# 3      0.559619   0.546670   0.522782   0.559559   0.531902   0.487599
# 4      9.780066   9.754476   9.688445  10.470594  12.075625  12.185854
#
#
# Year       2023       2024
# 0     36.765292  36.048834
# 1     16.332572  16.362968
# 2     11.109666  11.078726
# 3      0.478778   0.483182
# 4     12.382942  12.445733

# %%
ag_va.columns
# Out:
# MultiIndex([('Country Name',   ''),
#             (   'Indicator',   ''),
#             (       'Value', 2010),
#             (       'Value', 2011),
#             (       'Value', 2012),
#             (       'Value', 2013),
#             (       'Value', 2014),
#             (       'Value', 2015),
#             (       'Value', 2016),
#             (       'Value', 2017),
#             (       'Value', 2018),
#             (       'Value', 2019),
#             (       'Value', 2020),
#             (       'Value', 2021),
#             (       'Value', 2022),
#             (       'Value', 2023),
#             (       'Value', 2024)],
#            names=[None, 'Year'])

# %%
new_columns = ['Country Name', 'Indicator', '2010', '2011', '2012', '2013', '2014', '2015',
               '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
ag_va.columns = new_columns

# %%
ag_va.head()
# Out:
#   Country Name                                  Indicator       2010  \
# 0  Afghanistan  Agriculture Share of GDP US$, 2015 prices  29.927071
# 1      Albania  Agriculture Share of GDP US$, 2015 prices  18.838472
# 2      Algeria  Agriculture Share of GDP US$, 2015 prices   9.692806
# 3      Andorra  Agriculture Share of GDP US$, 2015 prices   0.466561
# 4       Angola  Agriculture Share of GDP US$, 2015 prices   7.517585
#
#         2011       2012       2013       2014       2015       2016  \
# 0  29.068881  27.282895  27.975367  28.394494  24.240142  26.525034
# 1  19.247593  20.001970  20.028236  20.065053  19.780173  19.537605
# 2  10.512314  10.898647  11.471144  11.327478  11.578715  11.421639
# 3   0.490616   0.601234   0.585626   0.537684   0.513420   0.521889
# 4   7.839903   7.733747   7.559591   8.359599   9.122534   9.722951
#
#         2017       2018       2019       2020       2021       2022  \
# 0  26.991481  26.587779  30.606768  32.618118  37.127710  36.999484
# 1  18.979104  18.460519  18.196361  19.071596  17.826641  17.010490
# 2  11.342714  11.600503  11.659044  11.900684  11.066839  11.231845
# 3   0.559619   0.546670   0.522782   0.559559   0.531902   0.487599
# 4   9.780066   9.754476   9.688445  10.470594  12.075625  12.185854
#
#         2023       2024
# 0  36.765292  36.048834
# 1  16.332572  16.362968
# 2  11.109666  11.078726
# 3   0.478778   0.483182
# 4  12.382942  12.445733

# %%
ag_va.to_excel('preclean_data\\Share of Food VA in GDP.xlsx', index=False)

# %%
wage_food = pd.read_excel('raw_data\\Wage in the food industry.xlsx',
                          na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(wage_food.columns. to_list())
# Out:
# ['ref_area.label', 'source.label', 'indicator.label', 'sex.label', 'classif1.label', 'classif2.label', 'time', 'obs_value', 'obs_status.label', 'note_classif.label', 'note_indicator.label', 'note_source.label']

# %%
wage_food.head()
# Out:
#   ref_area.label                        source.label  \
# 0          Aruba  PC - Population and Housing Census
# 1          Aruba  PC - Population and Housing Census
# 2          Aruba  PC - Population and Housing Census
# 3          Aruba  PC - Population and Housing Census
# 4          Aruba  PC - Population and Housing Census
#
#                                      indicator.label sex.label  \
# 0  Average monthly earnings of employees by sex a...     Total
# 1  Average monthly earnings of employees by sex a...     Total
# 2  Average monthly earnings of employees by sex a...     Total
# 3  Average monthly earnings of employees by sex a...     Total
# 4  Average monthly earnings of employees by sex a...     Total
#
#                                   classif1.label            classif2.label  \
# 0        Economic activity (Broad sector): Total  Currency: Local currency
# 1        Economic activity (Broad sector): Total      Currency: 2021 PPP $
# 2        Economic activity (Broad sector): Total    Currency: U.S. dollars
# 3  Economic activity (Broad sector): Agriculture  Currency: Local currency
# 4  Economic activity (Broad sector): Agriculture      Currency: 2021 PPP $
#
#    time  obs_value obs_status.label note_classif.label  \
# 0  2010   3013.000              NaN                NaN
# 1  2010   1860.382              NaN                NaN
# 2  2010   1683.240              NaN                NaN
# 3  2010   2187.000              NaN                NaN
# 4  2010   1350.367              NaN                NaN
#
#                                 note_indicator.label  \
# 0  Job coverage: Main job currently held | Workin...
# 1  Job coverage: Main job currently held | Workin...
# 2  Job coverage: Main job currently held | Workin...
# 3  Job coverage: Main job currently held | Workin...
# 4  Job coverage: Main job currently held | Workin...
#
#                   note_source.label
# 0  Data reference period: September
# 1  Data reference period: September
# 2  Data reference period: September
# 3  Data reference period: September
# 4  Data reference period: September

# %%
wage_food = wage_food[wage_food['sex.label'] == 'Total']

# %%
wage_food = wage_food[wage_food['classif1.label'] == 'Economic activity (Broad sector): Agriculture']

# %%
wage_food = wage_food[wage_food['classif2.label'] == 'Currency: U.S. dollars']
wage_food.head()
# Out:
#     ref_area.label                                source.label  \
# 5            Aruba          PC - Population and Housing Census
# 245    Afghanistan                   LFS - Labour Force Survey
# 344    Afghanistan  HIES - Households Living Conditions Survey
# 593         Angola                     LFS - Employment Survey
# 854         Angola                     LFS - Employment Survey
#
#                                        indicator.label sex.label  \
# 5    Average monthly earnings of employees by sex a...     Total
# 245  Average monthly earnings of employees by sex a...     Total
# 344  Average monthly earnings of employees by sex a...     Total
# 593  Average monthly earnings of employees by sex a...     Total
# 854  Average monthly earnings of employees by sex a...     Total
#
#                                     classif1.label          classif2.label  \
# 5    Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 245  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 344  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 593  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 854  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
#
#      time  obs_value obs_status.label note_classif.label  \
# 5    2010   1221.788              NaN                NaN
# 245  2020    134.013  Break in series                NaN
# 344  2014     94.035              NaN                NaN
# 593  2021     48.200              NaN                NaN
# 854  2019     83.328  Break in series                NaN
#
#                                   note_indicator.label  \
# 5    Job coverage: Main job currently held | Workin...
# 245  Currency: AFG - Afghani (AFN) | Break in serie...
# 344                      Currency: AFG - Afghani (AFN)
# 593                       Currency: AGO - Kwanza (AOA)
# 854  Currency: AGO - Kwanza (AOA) | Break in series...
#
#                                      note_source.label
# 5                     Data reference period: September
# 245  Repository: ILO-STATISTICS - Micro data proces...
# 344  Repository: ILO-STATISTICS - Micro data proces...
# 593  Repository: ILO-STATISTICS - Micro data proces...
# 854  Repository: ILO-STATISTICS - Micro data proces...

# %%
wage_food = wage_food[['ref_area.label', 'indicator.label', 'classif1.label', 'classif2.label', 'time', 'obs_value']]

# %%
wage_food = wage_food.rename(columns={'ref_area.label': 'Country Name',
                          'indicator.label': 'Indicator',            
                          'classif1.label': 'Sector',
                          'classif2.label': 'Currency',
                          'time': 'date',
                          'obs_value': 'value'})
wage_food.head()
# Out:
#     Country Name                                          Indicator  \
# 5          Aruba  Average monthly earnings of employees by sex a...
# 245  Afghanistan  Average monthly earnings of employees by sex a...
# 344  Afghanistan  Average monthly earnings of employees by sex a...
# 593       Angola  Average monthly earnings of employees by sex a...
# 854       Angola  Average monthly earnings of employees by sex a...
#
#                                             Sector                Currency  \
# 5    Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 245  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 344  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 593  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 854  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
#
#      date     value
# 5    2010  1221.788
# 245  2020   134.013
# 344  2014    94.035
# 593  2021    48.200
# 854  2019    83.328

# %%
wage_food.to_excel('preclean_data\\Wage in the food industry_long.xlsx', index=False)

# %%
wage_food = wage_food.pivot(index=['Country Name', 'Indicator', 'Sector', 'Currency'], columns='date')

# %%
wage_food = wage_food.reset_index()
wage_food.columns
# Out:
# MultiIndex([('Country Name',   ''),
#             (   'Indicator',   ''),
#             (      'Sector',   ''),
#             (    'Currency',   ''),
#             (       'value', 1990),
#             (       'value', 1991),
#             (       'value', 1992),
#             (       'value', 1993),
#             (       'value', 1994),
#             (       'value', 1995),
#             (       'value', 1996),
#             (       'value', 1997),
#             (       'value', 1998),
#             (       'value', 1999),
#             (       'value', 2000),
#             (       'value', 2001),
#             (       'value', 2002),
#             (       'value', 2003),
#             (       'value', 2004),
#             (       'value', 2005),
#             (       'value', 2006),
#             (       'value', 2007),
#             (       'value', 2008),
#             (       'value', 2009),
#             (       'value', 2010),
#             (       'value', 2011),
#             (       'value', 2012),
#             (       'value', 2013),
#             (       'value', 2014),
#             (       'value', 2015),
#             (       'value', 2016),
#             (       'value', 2017),
#             (       'value', 2018),
#             (       'value', 2019),
#             (       'value', 2020),
#             (       'value', 2021),
#             (       'value', 2022),
#             (       'value', 2023),
#             (       'value', 2024)],
#            names=[None, 'date'])

# %%
# Create new column names
new_columns = []
for col in wage_food.columns:
    if col[0] in ['Country Name', 'Indicator', 'Sector', 'Currency']:
        # Keep the names from the first level
        new_columns.append(col[0])
    else:
        # For the 'value' columns, use the year (second level)
        new_columns.append(str(col[1]))  # Convert year to string

# %%
wage_food.columns = new_columns

# %%
wage_food.head()
# Out:
#           Country Name                                          Indicator  \
# 0          Afghanistan  Average monthly earnings of employees by sex a...
# 1              Albania  Average monthly earnings of employees by sex a...
# 2               Angola  Average monthly earnings of employees by sex a...
# 3  Antigua and Barbuda  Average monthly earnings of employees by sex a...
# 4            Argentina  Average monthly earnings of employees by sex a...
#
#                                           Sector                Currency  \
# 0  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 1  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 2  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 3  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
# 4  Economic activity (Broad sector): Agriculture  Currency: U.S. dollars
#
#    1990  1991  1992  1993  1994  1995  ...     2015     2016     2017  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  268.336  274.379  304.487
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN  839.116
#
#       2018     2019     2020     2021     2022     2023     2024
# 0      NaN      NaN  134.013      NaN      NaN      NaN      NaN
# 1  341.766  336.010  307.032  344.484  358.549      NaN      NaN
# 2      NaN   83.328      NaN   48.200      NaN      NaN      NaN
# 3  477.793      NaN      NaN      NaN      NaN      NaN      NaN
# 4  569.864  549.519  451.296  468.700  577.779  633.377  657.868
#
# [5 rows x 39 columns]

# %%
wage_food.to_excel('preclean_data\\Wage in the food industry_wide.xlsx', index=False)

# %%
emp_share = pd.read_excel('raw_data\\Employment by industry.xlsx',
                          na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(emp_share.columns.to_list())
# Out:
# ['ref_area.label', 'indicator.label', 'sex.label', 'classif1.label', 'time', 'obs_value', 'obs_status.label', 'note_classif.label', 'note_indicator.label', 'note_source.label']

# %%
emp_share.head()
# Out:
#   ref_area.label                                    indicator.label sex.label  \
# 0          Aruba  Employment by sex and economic activity (thous...     Total
# 1          Aruba  Employment by sex and economic activity (thous...     Total
# 2          Aruba  Employment by sex and economic activity (thous...     Total
# 3          Aruba  Employment by sex and economic activity (thous...     Total
# 4          Aruba  Employment by sex and economic activity (thous...     Total
#
#                                       classif1.label  time  obs_value  \
# 0            Economic activity (Broad sector): Total  2011     47.915
# 1      Economic activity (Broad sector): Agriculture  2011      0.286
# 2  Economic activity (Broad sector): Non-agriculture  2011     47.629
# 3         Economic activity (Broad sector): Industry  2011      6.728
# 4         Economic activity (Broad sector): Services  2011     40.763
#
#   obs_status.label note_classif.label note_indicator.label note_source.label
# 0              NaN                NaN                  NaN               NaN
# 1              NaN                NaN                  NaN               NaN
# 2              NaN                NaN                  NaN               NaN
# 3              NaN                NaN                  NaN               NaN
# 4              NaN                NaN                  NaN               NaN

# %%
emp_share.shape
# Out:
# (398498, 10)

# %%
emp_share = emp_share[emp_share['sex.label'] == 'Total']
emp_share.shape
# Out:
# (140395, 10)

# %%
emp_share = emp_share[(emp_share['classif1.label'] == 'Economic activity (Broad sector): Total') | (emp_share['classif1.label'] == 'Economic activity (Broad sector): Agriculture')]
emp_share.shape
# Out:
# (9307, 10)

# %%
emp_share = emp_share[['ref_area.label', 'indicator.label', 'classif1.label', 'time', 'obs_value']]

# %%
emp_share.head()
# Out:
#     ref_area.label                                    indicator.label  \
# 0            Aruba  Employment by sex and economic activity (thous...
# 1            Aruba  Employment by sex and economic activity (thous...
# 90           Aruba  Employment by sex and economic activity (thous...
# 91           Aruba  Employment by sex and economic activity (thous...
# 189          Aruba  Employment by sex and economic activity (thous...
#
#                                     classif1.label  time  obs_value
# 0          Economic activity (Broad sector): Total  2011     47.915
# 1    Economic activity (Broad sector): Agriculture  2011      0.286
# 90         Economic activity (Broad sector): Total  2010     46.526
# 91   Economic activity (Broad sector): Agriculture  2010      0.296
# 189        Economic activity (Broad sector): Total  2007     51.607

# %%
emp_share = emp_share.pivot(index=['ref_area.label', 'indicator.label', 'time'], columns='classif1.label').reset_index()
emp_share.head()
# Out:
#                ref_area.label  \
# classif1.label
# 0                 Afghanistan
# 1                 Afghanistan
# 2                 Afghanistan
# 3                 Afghanistan
# 4                 Afghanistan
#
#                                                   indicator.label  time  \
# classif1.label
# 0               Employment by sex and economic activity (thous...  2008
# 1               Employment by sex and economic activity (thous...  2012
# 2               Employment by sex and economic activity (thous...  2014
# 3               Employment by sex and economic activity (thous...  2017
# 4               Employment by sex and economic activity (thous...  2020
#
#                                                    obs_value  \
# classif1.label Economic activity (Broad sector): Agriculture
# 0                                                   4426.731
# 1                                                   2477.079
# 2                                                   2824.353
# 3                                                   2740.235
# 4                                                   2714.301
#
#
# classif1.label Economic activity (Broad sector): Total
# 0                                             7486.564
# 1                                             6419.616
# 2                                             7003.038
# 3                                             6396.534
# 4                                             6078.509

# %%
# Create new column names
new_columns = ['ref_area.label', 'indicator.label', 'time', 'Economic activity (Broad sector): Agriculture', 'Economic activity (Broad sector): Total']

# %%
emp_share.columns = new_columns

# %%
emp_share['emp_share'] = emp_share['Economic activity (Broad sector): Agriculture']/emp_share['Economic activity (Broad sector): Total']

# %%
emp_share = emp_share[['ref_area.label', 'indicator.label', 'time', 'emp_share']]
emp_share = emp_share.rename(columns={'ref_area.label': 'Country Name',
                                      'indicator.label': 'Indicator',
                                      'time': 'date'})

# %%
emp_share = emp_share.pivot(index=['Country Name', 'Indicator'], columns='date').reset_index()
emp_share.columns
# Out:
# MultiIndex([('Country Name',   ''),
#             (   'Indicator',   ''),
#             (   'emp_share', 1947),
#             (   'emp_share', 1948),
#             (   'emp_share', 1949),
#             (   'emp_share', 1950),
#             (   'emp_share', 1951),
#             (   'emp_share', 1952),
#             (   'emp_share', 1953),
#             (   'emp_share', 1954),
#             (   'emp_share', 1955),
#             (   'emp_share', 1956),
#             (   'emp_share', 1957),
#             (   'emp_share', 1958),
#             (   'emp_share', 1959),
#             (   'emp_share', 1960),
#             (   'emp_share', 1961),
#             (   'emp_share', 1962),
#             (   'emp_share', 1963),
#             (   'emp_share', 1964),
#             (   'emp_share', 1965),
#             (   'emp_share', 1966),
#             (   'emp_share', 1967),
#             (   'emp_share', 1968),
#             (   'emp_share', 1969),
#             (   'emp_share', 1970),
#             (   'emp_share', 1971),
#             (   'emp_share', 1972),
#             (   'emp_share', 1973),
#             (   'emp_share', 1974),
#             (   'emp_share', 1975),
#             (   'emp_share', 1976),
#             (   'emp_share', 1977),
#             (   'emp_share', 1978),
#             (   'emp_share', 1979),
#             (   'emp_share', 1980),
#             (   'emp_share', 1981),
#             (   'emp_share', 1982),
#             (   'emp_share', 1983),
#             (   'emp_share', 1984),
#             (   'emp_share', 1985),
#             (   'emp_share', 1986),
#             (   'emp_share', 1987),
#             (   'emp_share', 1988),
#             (   'emp_share', 1989),
#             (   'emp_share', 1990),
#             (   'emp_share', 1991),
#             (   'emp_share', 1992),
#             (   'emp_share', 1993),
#             (   'emp_share', 1994),
#             (   'emp_share', 1995),
#             (   'emp_share', 1996),
#             (   'emp_share', 1997),
#             (   'emp_share', 1998),
#             (   'emp_share', 1999),
#             (   'emp_share', 2000),
#             (   'emp_share', 2001),
#             (   'emp_share', 2002),
#             (   'emp_share', 2003),
#             (   'emp_share', 2004),
#             (   'emp_share', 2005),
#             (   'emp_share', 2006),
#             (   'emp_share', 2007),
#             (   'emp_share', 2008),
#             (   'emp_share', 2009),
#             (   'emp_share', 2010),
#             (   'emp_share', 2011),
#             (   'emp_share', 2012),
#             (   'emp_share', 2013),
#             (   'emp_share', 2014),
#             (   'emp_share', 2015),
#             (   'emp_share', 2016),
#             (   'emp_share', 2017),
#             (   'emp_share', 2018),
#             (   'emp_share', 2019),
#             (   'emp_share', 2020),
#             (   'emp_share', 2021),
#             (   'emp_share', 2022),
#             (   'emp_share', 2023),
#             (   'emp_share', 2024)],
#            names=[None, 'date'])

# %%
emp_share.columns = ['Country Name', 'Indicator'] + [str(year) for year in range(1947, 2025)]

# %%
emp_share.head()
# Out:
#      Country Name                                          Indicator  1947  \
# 0     Afghanistan  Employment by sex and economic activity (thous...   NaN
# 1         Albania  Employment by sex and economic activity (thous...   NaN
# 2         Algeria  Employment by sex and economic activity (thous...   NaN
# 3  American Samoa  Employment by sex and economic activity (thous...   NaN
# 4          Angola  Employment by sex and economic activity (thous...   NaN
#
#    1948  1949  1950  1951  1952  1953  1954  ...      2015      2016  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.411782  0.400308
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.086558  0.083441
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
#
#        2017      2018      2019      2020      2021      2022      2023  2024
# 0  0.428394       NaN       NaN  0.446541  0.487952       NaN       NaN   NaN
# 1  0.380772  0.372858  0.364169  0.360409  0.337481  0.339269  0.322701   NaN
# 2  0.101496       NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 4       NaN       NaN  0.518941       NaN  0.557627  0.514927       NaN   NaN
#
# [5 rows x 80 columns]

# %%
emp_share.to_excel('preclean_data\\Employment by industry.xlsx', index=False)

# %%
food_price = pd.read_excel('raw_data\\Food price index.xls',
                           na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(food_price.columns.to_list())
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', '2010 [2010]', '2010 [2010].1', '2010 [2010].2', '2011 [2011]', '2011 [2011].1', '2011 [2011].2', '2012 [2012]', '2012 [2012].1', '2012 [2012].2', '2013 [2013]', '2013 [2013].1', '2013 [2013].2', '2014 [2014]', '2014 [2014].1', '2014 [2014].2', '2015 [2015]', '2015 [2015].1', '2015 [2015].2', '2016 [2016]', '2016 [2016].1', '2016 [2016].2', '2017 [2017]', '2017 [2017].1', '2017 [2017].2', '2018 [2018]', '2018 [2018].1', '2018 [2018].2', '2019 [2019]', '2019 [2019].1', '2019 [2019].2', '2020 [2020]', '2020 [2020].1', '2020 [2020].2', '2021 [2021]', '2021 [2021].1', '2021 [2021].2', '2022 [2022]', '2022 [2022].1', '2022 [2022].2', '2023 [2023]', '2023 [2023].1', '2023 [2023].2', '2024 [2024]', '2024 [2024].1', '2024 [2024].2']

# %%
food_price.head()
# Out:
#           Unnamed: 0                     Unnamed: 1  \
# 0                NaN                            NaN
# 1  Afghanistan [004]  Value US$, 2015 prices [6179]
# 2  Afghanistan [004]  Value US$, 2015 prices [6179]
# 3      Albania [008]  Value US$, 2015 prices [6179]
# 4      Albania [008]  Value US$, 2015 prices [6179]
#
#                                           Unnamed: 2 2010 [2010]  \
# 0                                                NaN        Unit
# 1                               GDP Deflator [22024]         USD
# 2  Value Added Deflator (Agriculture, forestry an...         USD
# 3                               GDP Deflator [22024]         USD
# 4  Value Added Deflator (Agriculture, forestry an...         USD
#
#   2010 [2010].1                      2010 [2010].2 2011 [2011] 2011 [2011].1  \
# 0         Value                   Flag Description        Unit         Value
# 1    101.368737  Figure from external organization         USD    111.212507
# 2    100.491475  Figure from external organization         USD    111.233985
# 3    114.460966  Figure from external organization         USD    120.639493
# 4     109.09877  Figure from external organization         USD    114.241683
#
#                        2011 [2011].2 2012 [2012]  ...  \
# 0                   Flag Description        Unit  ...
# 1  Figure from external organization         USD  ...
# 2  Figure from external organization         USD  ...
# 3  Figure from external organization         USD  ...
# 4  Figure from external organization         USD  ...
#
#                        2021 [2021].2 2022 [2022] 2022 [2022].1  \
# 0                   Flag Description        Unit         Value
# 1  Figure from external organization         USD     88.323325
# 2  Figure from external organization         USD     80.450313
# 3  Figure from external organization         USD    132.098754
# 4  Figure from external organization         USD    144.619673
#
#                        2022 [2022].2 2023 [2023] 2023 [2023].1  \
# 0                   Flag Description        Unit         Value
# 1  Figure from external organization         USD     99.591629
# 2  Figure from external organization         USD     93.511802
# 3  Figure from external organization         USD    155.124994
# 4  Figure from external organization         USD     173.49786
#
#                        2023 [2023].2 2024 [2024] 2024 [2024].1  \
# 0                   Flag Description        Unit         Value
# 1  Figure from external organization         USD     121.46049
# 2  Figure from external organization         USD    118.894029
# 3  Figure from external organization         USD    174.708899
# 4  Figure from external organization         USD    196.280088
#
#       2024 [2024].2
# 0  Flag Description
# 1   Estimated value
# 2   Estimated value
# 3   Estimated value
# 4   Estimated value
#
# [5 rows x 48 columns]

# %%
food_price = food_price.rename(columns={'Unnamed: 0': 'Country Name',
                      'Unnamed: 1': 'Currency',
                      'Unnamed: 2': 'Indicator',
                      '2010 [2010].1': '2010',
                      '2011 [2011].1': '2011',
                      '2012 [2012].1': '2012',
                      '2013 [2013].1': '2013',
                      '2014 [2014].1': '2014',
                      '2015 [2015].1': '2015',
                      '2016 [2016].1': '2016',
                      '2017 [2017].1': '2017',
                      '2018 [2018].1': '2018',
                      '2019 [2019].1': '2019',
                      '2020 [2020].1': '2020',
                      '2021 [2021].1': '2021',
                      '2022 [2022].1': '2022',
                      '2023 [2023].1': '2023',
                      '2024 [2024].1': '2024'})
food_price.head()
# Out:
#         Country Name                       Currency  \
# 0                NaN                            NaN
# 1  Afghanistan [004]  Value US$, 2015 prices [6179]
# 2  Afghanistan [004]  Value US$, 2015 prices [6179]
# 3      Albania [008]  Value US$, 2015 prices [6179]
# 4      Albania [008]  Value US$, 2015 prices [6179]
#
#                                            Indicator 2010 [2010]        2010  \
# 0                                                NaN        Unit       Value
# 1                               GDP Deflator [22024]         USD  101.368737
# 2  Value Added Deflator (Agriculture, forestry an...         USD  100.491475
# 3                               GDP Deflator [22024]         USD  114.460966
# 4  Value Added Deflator (Agriculture, forestry an...         USD   109.09877
#
#                        2010 [2010].2 2011 [2011]        2011  \
# 0                   Flag Description        Unit       Value
# 1  Figure from external organization         USD  111.212507
# 2  Figure from external organization         USD  111.233985
# 3  Figure from external organization         USD  120.639493
# 4  Figure from external organization         USD  114.241683
#
#                        2011 [2011].2 2012 [2012]  ...  \
# 0                   Flag Description        Unit  ...
# 1  Figure from external organization         USD  ...
# 2  Figure from external organization         USD  ...
# 3  Figure from external organization         USD  ...
# 4  Figure from external organization         USD  ...
#
#                        2021 [2021].2 2022 [2022]        2022  \
# 0                   Flag Description        Unit       Value
# 1  Figure from external organization         USD   88.323325
# 2  Figure from external organization         USD   80.450313
# 3  Figure from external organization         USD  132.098754
# 4  Figure from external organization         USD  144.619673
#
#                        2022 [2022].2 2023 [2023]        2023  \
# 0                   Flag Description        Unit       Value
# 1  Figure from external organization         USD   99.591629
# 2  Figure from external organization         USD   93.511802
# 3  Figure from external organization         USD  155.124994
# 4  Figure from external organization         USD   173.49786
#
#                        2023 [2023].2 2024 [2024]        2024     2024 [2024].2
# 0                   Flag Description        Unit       Value  Flag Description
# 1  Figure from external organization         USD   121.46049   Estimated value
# 2  Figure from external organization         USD  118.894029   Estimated value
# 3  Figure from external organization         USD  174.708899   Estimated value
# 4  Figure from external organization         USD  196.280088   Estimated value
#
# [5 rows x 48 columns]

# %%
food_price = food_price[['Country Name', 'Currency', 'Indicator', '2010', 
               '2011', '2012', '2013', '2014', '2015', '2016', '2017',
               '2018', '2019', '2020', '2021', '2022', '2023', '2024']]

# %%
food_price = food_price.drop(0)
food_price.head()
# Out:
#         Country Name                       Currency  \
# 1  Afghanistan [004]  Value US$, 2015 prices [6179]
# 2  Afghanistan [004]  Value US$, 2015 prices [6179]
# 3      Albania [008]  Value US$, 2015 prices [6179]
# 4      Albania [008]  Value US$, 2015 prices [6179]
# 5      Algeria [012]  Value US$, 2015 prices [6179]
#
#                                            Indicator        2010        2011  \
# 1                               GDP Deflator [22024]  101.368737  111.212507
# 2  Value Added Deflator (Agriculture, forestry an...  100.491475  111.233985
# 3                               GDP Deflator [22024]  114.460966  120.639493
# 4  Value Added Deflator (Agriculture, forestry an...   109.09877  114.241683
# 5                               GDP Deflator [22024]  114.350063  137.882068
#
#          2012        2013        2014 2015        2016        2017  \
# 1  111.552999  106.141015  101.652308  100   94.815368   97.314846
# 2  112.840986  102.590772   95.261805  100   92.571637   91.659138
# 3  113.684884  116.726131  118.747357  100  100.823802  106.617541
# 4  106.664661   114.02753  118.304682  100  102.435818  106.859006
# 5  139.374979   136.03009  133.583641  100   93.428564   98.028877
#
#          2018        2019        2020        2021        2022        2023  \
# 1    94.70049   87.855273   92.531648   88.571653   88.323325   99.591629
# 2    81.70547   74.507451   85.035317   80.150291   80.450313   93.511802
# 3  119.319379  118.771659  120.920822   131.29549  132.098754  155.124994
# 4  119.118827  120.031253  121.894875  135.209948  144.619673   173.49786
# 5   99.607893   96.845241   86.592278   93.932063  109.829683  115.836076
#
#          2024
# 1   121.46049
# 2  118.894029
# 3  174.708899
# 4  196.280088
# 5   125.14894

# %%
food_price = pd.melt(food_price, id_vars=['Country Name', 'Currency', 'Indicator'], var_name='year', value_name='value')

# %%
food_price = food_price.pivot(index=['Country Name', 'Currency', 'year'], columns='Indicator').reset_index()
food_price.columns
# Out:
# MultiIndex([('Country Name', ...),
#             (    'Currency', ...),
#             (        'year', ...),
#             (       'value', ...),
#             (       'value', ...)],
#            names=[None, 'Indicator'])

# %%
new_columns = ['Country Name', 'Currency', 'Year', 'GDP Deflator', 'Agri Deflator']

# %%
food_price.columns = new_columns

# %%
food_price['Food Price'] = food_price['Agri Deflator']/food_price['GDP Deflator']

# %%
food_price = food_price[['Country Name', 'Year', 'Food Price']]

# %%
food_price= food_price.pivot(index='Country Name', columns='Year').reset_index()
food_price.columns
# Out:
# MultiIndex([('Country Name',     ''),
#             (  'Food Price', '2010'),
#             (  'Food Price', '2011'),
#             (  'Food Price', '2012'),
#             (  'Food Price', '2013'),
#             (  'Food Price', '2014'),
#             (  'Food Price', '2015'),
#             (  'Food Price', '2016'),
#             (  'Food Price', '2017'),
#             (  'Food Price', '2018'),
#             (  'Food Price', '2019'),
#             (  'Food Price', '2020'),
#             (  'Food Price', '2021'),
#             (  'Food Price', '2022'),
#             (  'Food Price', '2023'),
#             (  'Food Price', '2024')],
#            names=[None, 'Year'])

# %%
new_columns = ['Country Name'] + [str(year) for year in range(2010, 2025)]
food_price.columns = new_columns

# %%
food_price['Indicator'] = 'Relative price of staple foods'

# %%
food_price = food_price[['Country Name', 'Indicator', '2010', '2021', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', 
                         '2020', '2021', '2022', '2023', '2024']]
food_price.head()
# Out:
#         Country Name                       Indicator      2010      2021  \
# 0  Afghanistan [004]  Relative price of staple foods  0.991346   0.90492
# 1      Albania [008]  Relative price of staple foods  0.953153  1.029814
# 2      Algeria [012]  Relative price of staple foods  0.873477  1.015234
# 3      Andorra [020]  Relative price of staple foods  0.999887  0.999894
# 4       Angola [024]  Relative price of staple foods  0.822112  0.959703
#
#        2012      2013      2014 2015      2016      2017      2018      2019  \
# 0  1.011546  0.966552  0.937134  1.0  0.976336  0.941882  0.862778   0.84807
# 1  0.938248  0.976881  0.996272  1.0  1.015988  1.002265  0.998319  1.010605
# 2   0.80475  0.858774  0.908093  1.0  1.069907  1.036427  1.023594  1.045861
# 3  0.999887  0.999887  0.999887  1.0  1.000211  0.999857  0.999447  0.999714
# 4  0.784824  0.860826  0.902801  1.0   1.01113  1.024226   0.88244  0.813611
#
#        2020      2021      2022      2023      2024
# 0  0.918986   0.90492  0.910861  0.938952   0.97887
# 1  1.008055  1.029814  1.094785  1.118439  1.123469
# 2  1.090423  1.015234  0.944918  1.177964  1.165327
# 3  0.999793  0.999894  0.999781  0.999403   0.98544
# 4   0.94995  0.959703  1.127355  1.202726  1.061243

# %%
food_price['Country Name'] = food_price['Country Name'].str.replace(r'\s*\[\d+\]\s*', '', regex=True)
food_price.head()
# Out:
#   Country Name                       Indicator      2010      2021      2012  \
# 0  Afghanistan  Relative price of staple foods  0.991346   0.90492  1.011546
# 1      Albania  Relative price of staple foods  0.953153  1.029814  0.938248
# 2      Algeria  Relative price of staple foods  0.873477  1.015234   0.80475
# 3      Andorra  Relative price of staple foods  0.999887  0.999894  0.999887
# 4       Angola  Relative price of staple foods  0.822112  0.959703  0.784824
#
#        2013      2014 2015      2016      2017      2018      2019      2020  \
# 0  0.966552  0.937134  1.0  0.976336  0.941882  0.862778   0.84807  0.918986
# 1  0.976881  0.996272  1.0  1.015988  1.002265  0.998319  1.010605  1.008055
# 2  0.858774  0.908093  1.0  1.069907  1.036427  1.023594  1.045861  1.090423
# 3  0.999887  0.999887  1.0  1.000211  0.999857  0.999447  0.999714  0.999793
# 4  0.860826  0.902801  1.0   1.01113  1.024226   0.88244  0.813611   0.94995
#
#        2021      2022      2023      2024
# 0   0.90492  0.910861  0.938952   0.97887
# 1  1.029814  1.094785  1.118439  1.123469
# 2  1.015234  0.944918  1.177964  1.165327
# 3  0.999894  0.999781  0.999403   0.98544
# 4  0.959703  1.127355  1.202726  1.061243

# %%
food_price.to_excel('preclean_data\\Food price index.xlsx', index=False)

# %%
gdp_pc = pd.read_excel('raw_data\\GDP per capita (current US$).xls',
                       na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(gdp_pc.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
gdp_pc.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  186.121835  186.941781  197.402402  225.440494  208.999748
# 2  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 3  NY.GDP.PCAP.CD  121.939925  127.454189  133.827044  139.008291  148.549379
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
#          1965  ...          2015          2016          2017          2018  \
# 0         NaN  ...  27458.225331  27441.529662  28440.051964  30082.127645
# 1  226.876513  ...   1479.615260   1329.807285   1520.212231   1538.901679
# 2         NaN  ...    565.569730    522.082216    525.469771    491.337221
# 3  155.565216  ...   1860.727694   1630.039447   1574.230560   1720.140280
# 4         NaN  ...   3213.902611   1807.952941   2437.259712   2538.591391
#
#            2019          2020          2021          2022          2023  \
# 0  31096.205074  22855.932320  27200.061079  30559.533535  33984.790620
# 1   1493.817938   1344.103210   1522.393346   1628.318944   1510.742951
# 2    496.602504    510.787063    356.496214    357.261153    413.757895
# 3   1798.340685   1680.039332   1765.954788   1796.668633   1599.392983
# 4   2189.855714   1449.922867   1925.874661   2929.694455   2309.534130
#
#           2024
# 0          NaN
# 1  1567.635839
# 2          NaN
# 3  1284.154441
# 4  2122.083690
#
# [5 rows x 69 columns]

# %%
gdp_pc = filter_countries(gdp_pc, 'Country Name')
gdp_pc.head()
# Out:
# Original shape: (266, 69), Filtered shape: (65, 69)
# Countries kept: 65
#    Country Name Country Code                Indicator Name  Indicator Code  \
# 5       Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 9     Argentina          ARG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 10      Armenia          ARM  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 14      Austria          AUT  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 17      Belgium          BEL  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#            1960         1961         1962         1963         1964  \
# 5           NaN          NaN          NaN          NaN          NaN
# 9    778.251707   971.338043   870.217491   852.972425  1176.200862
# 10          NaN          NaN          NaN          NaN          NaN
# 14   939.914815  1036.728204  1093.014191  1172.557446  1275.457153
# 17  1290.286072  1367.788852  1457.265170  1555.022932  1724.018942
#
#            1965  ...          2015          2016          2017          2018  \
# 5           NaN  ...   3981.726623   4168.375445   4614.047969   5365.488802
# 9   1281.833380  ...  13679.626498  12699.962314  14532.500931  11752.799892
# 10          NaN  ...   3512.393503   3524.424769   3869.053739   4196.005623
# 14  1381.077258  ...  43915.228021  45061.499392  47163.742578  51194.074984
# 17  1859.509987  ...  40893.804538  41854.549830  44035.323936  47487.210039
#
#             2019          2020          2021          2022          2023  \
# 5    5460.430509   5370.777500   6413.282808   6846.426694   8575.171346
# 9    9955.974787   8535.599380  10738.017922  13935.681111  14187.482725
# 10   4597.228874   4268.680933   4685.179971   6571.974455   8125.273958
# 14  49885.994736  48716.409890  53648.719074  52176.664914  56033.573792
# 17  46716.622747  45906.287581  51658.238295  50822.251854  54690.094273
#
#             2024
# 5   10011.627986
# 9   13858.203980
# 10   8500.605225
# 14  56833.196047
# 17  55954.610626
#
# [5 rows x 69 columns]

# %%
gdp_pc.to_excel('preclean_data\\GDP per capita (current US$).xlsx', index=False)

# %%
gdp_growth = pd.read_excel('raw_data\\GDP per capita growth (annual %).xls',
                           na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(gdp_growth.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
gdp_growth = filter_countries(gdp_growth, 'Country Name')
gdp_growth.head()
# Out:
# Original shape: (266, 69), Filtered shape: (65, 69)
# Countries kept: 65
#    Country Name Country Code                    Indicator Name  \
# 5       Albania          ALB  GDP per capita growth (annual %)
# 9     Argentina          ARG  GDP per capita growth (annual %)
# 10      Armenia          ARM  GDP per capita growth (annual %)
# 14      Austria          AUT  GDP per capita growth (annual %)
# 17      Belgium          BEL  GDP per capita growth (annual %)
#
#        Indicator Code  1960      1961      1962      1963      1964      1965  \
# 5   NY.GDP.PCAP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 9   NY.GDP.PCAP.KD.ZG   NaN  3.697198 -2.481212 -6.851643  8.371062  8.853456
# 10  NY.GDP.PCAP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 14  NY.GDP.PCAP.KD.ZG   NaN  4.960717  2.021470  3.471466  5.419336  2.810013
# 17  NY.GDP.PCAP.KD.ZG   NaN  4.630257  4.794035  3.574354  5.949139  2.624445
#
#     ...      2015      2016      2017      2018      2019       2020  \
# 5   ...  2.525831  4.075198  3.378212  3.927526  2.498299  -2.756980
# 9   ...  1.660913 -3.024501  1.916396 -3.415537 -2.695067 -10.336110
# 10  ...  3.515995  0.611877  7.965446  5.568501  7.836084  -7.168665
# 14  ...  0.174260  1.018877  1.564307  1.986263  1.303503  -6.706394
# 17  ...  0.887876  0.682455  1.084312  1.415289  1.890719  -5.202440
#
#          2021       2022      2023      2024
# 5    9.984331   6.108948  5.137124  5.162522
# 9   10.148560   5.048195 -1.892950 -2.058403
# 10   5.771428  12.338334  8.479020  3.484216
# 14   4.339758   4.275933 -1.930146 -1.676594
# 17   5.771346   3.420168  0.281208  0.258325
#
# [5 rows x 69 columns]

# %%
gdp_growth.to_excel('preclean_data\\GDP per capita growth (annual %).xlsx', index=False)

# %%
inflation = pd.read_excel('raw_data\\Inflation, GDP deflator (annual %).xls',
                          na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(inflation.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
inflation = filter_countries(inflation, 'Country Name')
inflation.head()
# Out:
# Original shape: (266, 69), Filtered shape: (65, 69)
# Countries kept: 65
#    Country Name Country Code                      Indicator Name  \
# 5       Albania          ALB  Inflation, GDP deflator (annual %)
# 9     Argentina          ARG  Inflation, GDP deflator (annual %)
# 10      Armenia          ARM  Inflation, GDP deflator (annual %)
# 14      Austria          AUT  Inflation, GDP deflator (annual %)
# 17      Belgium          BEL  Inflation, GDP deflator (annual %)
#
#        Indicator Code  1960       1961       1962       1963       1964  \
# 5   NY.GDP.DEFL.KD.ZG   NaN        NaN        NaN        NaN        NaN
# 9   NY.GDP.DEFL.KD.ZG   NaN  20.310698  28.871842  25.591154  28.774617
# 10  NY.GDP.DEFL.KD.ZG   NaN        NaN        NaN        NaN        NaN
# 14  NY.GDP.DEFL.KD.ZG   NaN   5.087154   3.340203   3.678266   3.183788
# 17  NY.GDP.DEFL.KD.ZG   NaN   1.315469   1.667692   3.025797   4.642427
#
#          1965  ...       2015       2016       2017       2018       2019  \
# 5         NaN  ...   0.771576  -0.864265   2.725069   1.453287   1.000633
# 9   21.232935  ...  26.579992  41.119380  26.006379  42.033669  49.195579
# 10        NaN  ...   1.213910   0.268575   2.150642   2.787710   1.065623
# 14   5.321415  ...   2.292635   1.814751   0.975318   1.810480   1.473685
# 17   5.100713  ...   1.121839   1.895289   1.983163   1.717282   1.854241
#
#          2020       2021       2022        2023        2024
# 5    0.041044   3.444391   9.861583    6.066052    2.688874
# 9   40.083088  53.802088  69.876084  135.368876  207.921861
# 10   1.806593   6.900514   7.985879    2.673004    1.161269
# 14   2.593133   1.926129   4.754778    6.647654    3.050594
# 17   1.596117   2.742627   6.843976    4.508122    1.943705
#
# [5 rows x 69 columns]

# %%
inflation.to_excel('preclean_data\\Inflation, GDP deflator (annual %).xlsx', index=False)

# %%
enrollment = pd.read_excel('raw_data\\Secondary enrollment.xlsx',
                            na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(enrollment.columns.to_list())
# Out:
# ['Series Name', 'Series Code', 'Country Name', 'Country Code', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]', '2024 [YR2024]']

# %%
enrollment = filter_countries(enrollment, 'Country Name')
enrollment.head()
# Out:
# Original shape: (271, 19), Filtered shape: (65, 19)
# Countries kept: 65
#                                Series Name  Series Code Country Name  \
# 1   School enrollment, secondary (% gross)  SE.SEC.ENRR      Albania
# 7   School enrollment, secondary (% gross)  SE.SEC.ENRR    Argentina
# 8   School enrollment, secondary (% gross)  SE.SEC.ENRR      Armenia
# 11  School enrollment, secondary (% gross)  SE.SEC.ENRR      Austria
# 17  School enrollment, secondary (% gross)  SE.SEC.ENRR      Belarus
#
#    Country Code  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 1           ALB      93.681824      95.470528      97.608612     102.903210
# 7           ARG      99.070999     100.884560     102.709991     104.540863
# 8           ARM     107.732391      94.877403            NaN      86.872192
# 11          AUT     100.263969      99.672958     100.108727     101.173210
# 17          BLR     111.028999     108.989867     107.657786     104.523124
#
#     2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 1      103.321378     102.440729      99.170755      97.574370      98.822388
# 7      106.038902     107.504868     109.598328     110.377800     109.671242
# 8       86.520401      86.442139            NaN            NaN      83.024941
# 11     101.304810     101.411583     100.227989     100.337898     100.692596
# 17     103.510351     102.895731     102.969006     102.480850     101.596011
#
#     2019 [YR2019]  2020 [YR2020]  2021 [YR2021]  2022 [YR2022]  2023 [YR2023]  \
# 1       99.015154      95.929447      97.665033      97.322471      96.136877
# 7      110.460152     112.376732     115.735779     114.148117     105.574584
# 8       86.826063      88.508030      91.485374      91.710661      89.411103
# 11     101.543633     101.690559     102.307663     101.458000     100.504372
# 17     100.438744     100.575710     100.420639      99.060203      97.426600
#
#     2024 [YR2024]
# 1      108.355392
# 7             NaN
# 8       90.945871
# 11            NaN
# 17      94.790270

# %%
enrollment = enrollment.rename(columns={'2010 [YR2010]': '2010',
                           '2011 [YR2011]': '2011',
                           '2012 [YR2012]': '2012',
                           '2013 [YR2013]': '2013',
                           '2014 [YR2014]': '2014',
                           '2015 [YR2015]': '2015',
                           '2016 [YR2016]': '2016',
                           '2017 [YR2017]': '2017',
                           '2018 [YR2018]': '2018',
                           '2019 [YR2019]': '2019',
                           '2020 [YR2020]': '2020',
                           '2021 [YR2021]': '2021',
                           '2022 [YR2022]': '2022',
                           '2023 [YR2023]': '2023',
                           '2024 [YR2024]': '2024'})
enrollment.head()
# Out:
#                                Series Name  Series Code Country Name  \
# 1   School enrollment, secondary (% gross)  SE.SEC.ENRR      Albania
# 7   School enrollment, secondary (% gross)  SE.SEC.ENRR    Argentina
# 8   School enrollment, secondary (% gross)  SE.SEC.ENRR      Armenia
# 11  School enrollment, secondary (% gross)  SE.SEC.ENRR      Austria
# 17  School enrollment, secondary (% gross)  SE.SEC.ENRR      Belarus
#
#    Country Code        2010        2011        2012        2013        2014  \
# 1           ALB   93.681824   95.470528   97.608612  102.903210  103.321378
# 7           ARG   99.070999  100.884560  102.709991  104.540863  106.038902
# 8           ARM  107.732391   94.877403         NaN   86.872192   86.520401
# 11          AUT  100.263969   99.672958  100.108727  101.173210  101.304810
# 17          BLR  111.028999  108.989867  107.657786  104.523124  103.510351
#
#           2015        2016        2017        2018        2019        2020  \
# 1   102.440729   99.170755   97.574370   98.822388   99.015154   95.929447
# 7   107.504868  109.598328  110.377800  109.671242  110.460152  112.376732
# 8    86.442139         NaN         NaN   83.024941   86.826063   88.508030
# 11  101.411583  100.227989  100.337898  100.692596  101.543633  101.690559
# 17  102.895731  102.969006  102.480850  101.596011  100.438744  100.575710
#
#           2021        2022        2023        2024
# 1    97.665033   97.322471   96.136877  108.355392
# 7   115.735779  114.148117  105.574584         NaN
# 8    91.485374   91.710661   89.411103   90.945871
# 11  102.307663  101.458000  100.504372         NaN
# 17  100.420639   99.060203   97.426600   94.790270

# %%
enrollment.to_excel('preclean_data\\Secondary enrollment.xlsx', index=False)

# %%
transfers = pd.read_excel('raw_data\\Subsidies and other transfers.xls',
                          na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(transfers.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
transfers = filter_countries(transfers, 'Country Name')
transfers.head()
# Out:
# Original shape: (266, 69), Filtered shape: (65, 69)
# Countries kept: 65
#    Country Name Country Code                                Indicator Name  \
# 5       Albania          ALB  Subsidies and other transfers (% of expense)
# 9     Argentina          ARG  Subsidies and other transfers (% of expense)
# 10      Armenia          ARM  Subsidies and other transfers (% of expense)
# 14      Austria          AUT  Subsidies and other transfers (% of expense)
# 17      Belgium          BEL  Subsidies and other transfers (% of expense)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2015  \
# 5   GC.XPN.TRFT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  46.985575
# 9   GC.XPN.TRFT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  65.483600
# 10  GC.XPN.TRFT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  37.276318
# 14  GC.XPN.TRFT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  73.116848
# 17  GC.XPN.TRFT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  81.665101
#
#          2016       2017       2018       2019       2020       2021  \
# 5   51.979204  53.383339  53.402081  53.269567  54.700653  54.281205
# 9   63.768041  64.403323  66.257258  67.201552  77.220404  75.086401
# 10  46.094930  38.472619  40.211234  38.187382  41.130239  42.065928
# 14  73.433165  73.440133  74.075935  74.457594  75.905943  75.909688
# 17  82.689391  83.416628  84.186162  84.583563  85.296400  85.741444
#
#          2022       2023  2024
# 5   58.738313  58.631946   NaN
# 9   74.675824  68.763812   NaN
# 10  39.777432  40.791654   NaN
# 14  73.895450  74.140412   NaN
# 17  84.993667        NaN   NaN
#
# [5 rows x 69 columns]

# %%
transfers.to_excel('preclean_data\\Subsidies and other transfers.xlsx', index=False)

# %%
urban = pd.read_excel('raw_data\\Urban population (% of total population).xls',
                      na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(urban.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
urban = filter_countries(urban, 'Country Name')
urban.head()
# Out:
# Original shape: (266, 69), Filtered shape: (65, 69)
# Countries kept: 65
#    Country Name Country Code                            Indicator Name  \
# 5       Albania          ALB  Urban population (% of total population)
# 9     Argentina          ARG  Urban population (% of total population)
# 10      Armenia          ARM  Urban population (% of total population)
# 14      Austria          AUT  Urban population (% of total population)
# 17      Belgium          BEL  Urban population (% of total population)
#
#        Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 5   SP.URB.TOTL.IN.ZS  30.705  30.943  31.015  31.086  31.158  31.230  ...
# 9   SP.URB.TOTL.IN.ZS  73.611  74.217  74.767  75.309  75.844  76.369  ...
# 10  SP.URB.TOTL.IN.ZS  51.275  52.147  53.019  53.889  54.758  55.622  ...
# 14  SP.URB.TOTL.IN.ZS  64.720  64.814  64.863  64.913  64.962  65.011  ...
# 17  SP.URB.TOTL.IN.ZS  92.460  92.554  92.679  92.835  92.988  93.137  ...
#
#       2015    2016    2017    2018    2019    2020    2021    2022    2023  \
# 5   57.434  58.421  59.383  60.319  61.229  62.112  62.969  63.799  64.603
# 9   91.503  91.627  91.749  91.870  91.991  92.111  92.229  92.347  92.463
# 10  63.085  63.082  63.103  63.149  63.219  63.313  63.431  63.573  63.739
# 14  57.715  57.905  58.094  58.297  58.515  58.748  58.995  59.256  59.530
# 17  97.876  97.919  97.961  98.001  98.041  98.079  98.117  98.153  98.189
#
#       2024
# 5   65.380
# 9   92.579
# 10  63.929
# 14  59.819
# 17  98.224
#
# [5 rows x 69 columns]

# %%
urban.to_excel('preclean_data\\Urban population (% of total population).xlsx', index=False)

# %%
precip = pd.read_excel('raw_data\\Average precipitation in depth (mm per year).xls',
                       na_values=['..', '…', '', 'NULL', 'null', 'NA', 'n/a', '#N/A'])
print(precip.columns.to_list())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
precip = filter_countries(precip, 'Country Name')
precip.head()
# Out:
# Original shape: (266, 19), Filtered shape: (65, 19)
# Countries kept: 65
#    Country Name Country Code                                Indicator Name  \
# 5       Albania          ALB  Average precipitation in depth (mm per year)
# 9     Argentina          ARG  Average precipitation in depth (mm per year)
# 10      Armenia          ARM  Average precipitation in depth (mm per year)
# 14      Austria          AUT  Average precipitation in depth (mm per year)
# 17      Belgium          BEL  Average precipitation in depth (mm per year)
#
#     Indicator Code    2010    2011    2012    2013    2014    2015    2016  \
# 5   AG.LND.PRCP.MM  1485.0  1485.0  1485.0  1485.0  1485.0  1485.0  1485.0
# 9   AG.LND.PRCP.MM   591.0   591.0   591.0   591.0   591.0   591.0   591.0
# 10  AG.LND.PRCP.MM   562.0   562.0   562.0   562.0   562.0   562.0   562.0
# 14  AG.LND.PRCP.MM  1110.0  1110.0  1110.0  1110.0  1110.0  1110.0  1110.0
# 17  AG.LND.PRCP.MM   847.0   847.0   847.0   847.0   847.0   847.0   847.0
#
#       2017    2018    2019    2020    2021    2022  2023  2024
# 5   1485.0  1485.0  1485.0  1485.0  1485.0  1485.0   NaN   NaN
# 9    591.0   591.0   591.0   591.0   591.0   591.0   NaN   NaN
# 10   562.0   562.0   562.0   562.0   562.0   562.0   NaN   NaN
# 14  1110.0  1110.0  1110.0  1110.0  1110.0  1110.0   NaN   NaN
# 17   847.0   847.0   847.0   847.0   847.0   847.0   NaN   NaN

# %%
precip.to_excel('preclean_data\\Average precipitation in depth (mm per year).xlsx', index=False)

# %%
lpi_2010 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2010')
print(lpi_2010.columns.to_list())
# Out:
# ['Country', 'Code', 'score', 'lower bound', 'upper bound', 'rank', 'lower bound.1', 'upper bound.1', '% of highest performer', 'score.1', 'rank.1', 'score.2', 'rank.2', 'score.3', 'rank.3', 'score.4', 'rank.4', 'score.5', 'rank.5', 'score.6', 'rank.6']
# c:\Users\u.nurmatov\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
lpi_2010 = lpi_2010[['Country', 'score']]
lpi_2010.shape
# Out:
# (155, 2)

# %%
lpi_2012 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2012')
print(lpi_2012.columns.to_list())
# Out:
# ['Country', 'Code', 'score', 'lower bound', 'upper bound', 'rank', 'lower bound.1', 'upper bound.1', '% of highest performer', 'score.1', 'rank.1', 'score.2', 'rank.2', 'score.3', 'rank.3', 'score.4', 'rank.4', 'score.5', 'rank.5', 'score.6', 'rank.6']
# c:\Users\u.nurmatov\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
lpi_2012 = lpi_2012[['Country', 'score']]
lpi_2012.shape
# Out:
# (155, 2)

# %%
lpi_2014 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2014')
print(lpi_2014.columns.to_list())
# Out:
# ['Country', 'Code', 'score', 'lower bound', 'upper bound', 'rank', 'lower bound.1', 'upper bound.1', '% of highest performer', 'score.1', 'rank.1', 'score.2', 'rank.2', 'score.3', 'rank.3', 'score.4', 'rank.4', 'score.5', 'rank.5', 'score.6', 'rank.6']
# c:\Users\u.nurmatov\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
lpi_2014 = lpi_2014[['Country', 'score']]
lpi_2014.shape
# Out:
# (160, 2)

# %%
lpi_2016 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2016')
print(lpi_2016.columns.to_list())
# Out:
# ['Country', 'Code', 'score', 'lower bound', 'upper bound', 'rank', 'lower bound.1', 'upper bound.1', '% of highest performer', 'score.1', 'rank.1', 'score.2', 'rank.2', 'score.3', 'rank.3', 'score.4', 'rank.4', 'score.5', 'rank.5', 'score.6', 'rank.6']
# c:\Users\u.nurmatov\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
lpi_2016 = lpi_2016[['Country', 'score']]
lpi_2016.shape
# Out:
# (160, 2)

# %%
lpi_2018 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2018')
print(lpi_2018.columns.to_list())
# Out:
# ['Country', 'Code', 'score', 'lower bound', 'upper bound', 'rank', 'lower bound.1', 'upper bound.1', '% of highest performer', 'score.1', 'rank.1', 'score.2', 'rank.2', 'score.3', 'rank.3', 'score.4', 'rank.4', 'score.5', 'rank.5', 'score.6', 'rank.6']
# c:\Users\u.nurmatov\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
lpi_2018 = lpi_2018[['Country', 'score']]
lpi_2018.shape
# Out:
# (160, 2)

# %%
lpi_2023 = pd.read_excel('raw_data\\Logistic performance index.xlsx', sheet_name='2023')
print(lpi_2023.columns.to_list())
# Out:
# ['Economy', 'LPI Score', 'LPI Grouped Rank', 'Customs Score', 'Customs Grouped Rank', 'Infrastructure Score', 'Infrastructure Grouped Rank', 'International Shipments Score', 'International Shipments Grouped Rank', 'Logistics Competence and Quality Score', 'Logistics Competence and Quality Grouped Rank', 'Timeliness Score', 'Timeliness Grouped Rank', 'Tracking and Tracing Score', 'Tracking and Tracing Grouped Rank']

# %%
lpi_2023 = lpi_2023[['Economy', 'LPI Score']]
lpi_2023.shape
# Out:
# (139, 2)
